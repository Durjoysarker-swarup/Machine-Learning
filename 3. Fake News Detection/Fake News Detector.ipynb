# %% [markdown]
# # Fake News Detection

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd
df_true = pd.read_csv('True.csv')
df_fake = pd.read_csv('Fake.csv')

# %% [markdown]
# ### Add labels: 1 for real, 0 for fake

# %%
df_true["label"] = 1
df_fake["label"] = 0

# %% [markdown]
# ### Combine and Shuffle

# %% [markdown]
# #### Combine

# %%
df = pd.concat([df_true,df_fake])
#df.to_csv("combined_data.csv", index=False)

# %% [markdown]
# #### Shuffle

# %%
# Gives 50% data randomly
#df_fifty_percent = df.sample(frac= .5)

# %%
df = df.sample(frac= 1).reset_index(drop=True)
#df.to_csv("shuffled_combined_data.csv", index=False)

# %%
#df_confusion = df.sample(frac= 0.001).reset_index(drop=True)

# %% [markdown]
# ### Splitting the dataset into the training set and the test set

# %%
short_combined_data = pd.read_csv("short_combined_data.csv")

# %%
from sklearn.model_selection import train_test_split
x=short_combined_data["text"]
y=short_combined_data["label"]
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ### Exploiting the TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# stop_word = "english" -> extract the common words like(the,is,am,are)
# max_df = maximum document frequency, if the word is present in the 70% of each document. then is will be a common word and exclude the word by the command
tfidf_vectorizer = TfidfVectorizer(stop_words='english', max_df = 0.7)

# %% [markdown]
# #### Fitting and Trasforming the data

# %%
tfidf_vectorizer.fit_transform(x_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2685 stored elements and shape (16, 1967)>
